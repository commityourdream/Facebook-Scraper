# %%
import json

# %%
content=[{
   "id": "441918235968654",
   "name": "buysmaart",
   "conversations": {
      "data": [
         {
            "messages": {
               "data": [
                  {
                     "created_time": "2018-03-14T21:53:13+0000",
                     "message": "Thanks for reaching out. We will start the blogging soon. It is not for sale.",
                     "id": "m_mid.$cAAHLGX9F7lFoV8YC0liJoC6SsZRI"
                  },
                  {
                     "created_time": "2018-03-14T04:52:22+0000",
                     "message": "Hi there,\n\nI'm looking to start a site and noticed that your blog has been dormant for some time.\n\nI would love to buy your site if it is for sale. Would you be interested?\n\nBest,\nAdeendren",
                     "id": "m_mid.$cAAHLGX9F7lFoVB9kQViItoaFCfIW"
                  }
               ],
               "paging": {
                  "cursors": {
                     "before": "QVFIUkhuLXpXMmd1UmZAzbWRtZAGxBSVNXR015aU1jeG0tTk1XRnI1QnIzbTZA0WnlDaHFsNU1qWUF1cGJSNUVTWks1eFd2V0NMUEdCYkJJV3JUOEJ3RC1TdUFOYlpHblRteHhqbEoyYTdxUjZAnWHlrMU5KeUdCX09YZAnRHT18wazJ3ZAUEx",
                     "after": "QVFIUnFwNEFFN2d1bC1UNTRodUZAIVTVRNzRaQUNHcWtnOTY2c2s4d2huOFRzci1hOGtNeTZAJMk1TelRXMnl3TkFoajNNR2RXUzFwcWZA6S0ZAFVUJ4VHZAFRXBEb0haMXBqSUtEMVQ2NjFtVDV1cWFhQ1JERHFHcU1sRzR2S2cwQWN4SjFR"
                  }
               }
            },
            "id": "t_620671001609400"
         },
         {
            "messages": {
               "data": [
                  {
                     "created_time": "2017-11-24T09:21:00+0000",
                     "message": "Thanks",
                     "id": "m_mid.$cAAHLH0zXoyxmHpnNqFf7VSCQIQcq"
                  },
                  {
                     "created_time": "2017-11-24T09:20:57+0000",
                     "message": "Okay",
                     "id": "m_mid.$cAAHLH0zXoyxmHpnBRFf7VR14ZDYh"
                  },
                  {
                     "created_time": "2017-11-20T13:44:32+0000",
                     "message": "We will touchbase in Feb 2018 as discussed",
                     "id": "m_mid.$cAAHLH0zXoyxmCvGiQlf2axZB4koB"
                  },
                  {
                     "created_time": "2017-11-20T13:44:21+0000",
                     "message": "I am not promoting any campaigns currently. Doing a minimal campaign on Google",
                     "id": "m_mid.$cAAHLH0zXoyxmCvF3Qlf2awt4LvbA"
                  },
                  {
                     "created_time": "2017-11-20T10:45:33+0000",
                     "message": "you are promoting the campaigns directly or also through some network?",
                     "id": "m_mid.$cAAHLH0zXoyxmCk3Filf2Qh3JH4Wy"
                  },
                  {
                     "created_time": "2017-11-20T10:14:32+0000",
                     "message": "how are you?",
                     "id": "m_mid.$cAAHLH0zXoyxmCjFhx1f2OwSyp5Dm"
                  },
                  {
                     "created_time": "2017-11-20T10:04:40+0000",
                     "message": "hi",
                     "id": "m_mid.$cAAHLH0zXoyxmCihX-Ff2OMLygLrH"
                  },
                  {
                     "created_time": "2017-11-20T10:04:11+0000",
                     "message": "How are you?",
                     "id": "m_mid.$cAAHLH0zXoyxmCifnwVf2OKZKDSCT"
                  },
                  {
                     "created_time": "2017-11-20T10:04:07+0000",
                     "message": "Hello Giri.",
                     "id": "m_mid.$cAAHLH0zXoyxmCifZUFf2OKK42P5S"
                  },
                  {
                     "created_time": "2017-10-09T07:04:16+0000",
                     "message": "Thanks and sure",
                     "id": "m_mid.$cAAHLH0zXoyxlMTgXUle__LOx10Fv"
                  }
               ],
               "paging": {
                  "cursors": {
                     "before": "QVFI

         },
         {
            "messages": {
               "data": [
                  {
                     "created_time": "2016-07-30T14:21:45+0000",
                     "message": "I am sanjay ravariya",
                     "id": "m_mid.1469888505838:af3c2fa40a8f883575"
                  },
                  {
                     "created_time": "2016-07-30T14:21:40+0000",
                     "message": "Pic*",
                     "id": "m_mid.1469888500948:9bff5c413ec5002d67"
                  },
                  {
                     "created_time": "2016-07-30T14:21:39+0000",
                     "message": "",
                     "id": "m_mid.1469888499810:0fd22f32c5ca4a0291"
                  },
                  {
                     "created_time": "2016-07-30T14:21:39+0000",
                     "message": "This is the oic",
                     "id": "m_mid.1469888499162:35b3b87f1e15410059"
                  },
                  {
                     "created_time": "2016-07-30T14:15:29+0000",
                     "message": "How should i upload my pic in this page?",
                     "id": "m_mid.1469888129175:600c7d90a589ba5b41"
                  },
                  {
                     "created_time": "2016-07-30T14:15:13+0000",
                     "message": "Hie",
                     "id": "m_mid.1469888113045:35cc7848e715dd3101"
                  }
               ],
               "paging": {
                  "cursors": {
                     "before": "QVFIUkdZAamdsLS14cExuU3l6REpUTlAwYmctOHljakZAkZA2tGWWR1YXEwcDRJQ3B4U09FRVRqZA3VtTnN6WGtKeVJWb2tNbDVLbVV6d1lOZAFRnbEx4Q1JHQWk3czlGVTJDQkFvamEtVDF3WkhBQ0pQT2p6LVgwMVZAENUlEdzMyZA3BZAY0Nj",
                     "after": "QVFIUi1kNk96WW8tZA0JKOEoxT0VpMkx1SnRMSmpmRUtHcXUtbnF4MFl2Tm1KNEdJTnEyeXdhX1NZAdzlXTWNJdTM5UFdUdEJLcTZAIcGgyOUZALaUcxa2ZAlUFI4VG1NaTlnMWhTZAHMybHdRUHRrRHYxemRqZA1Btb0ZADUzdGcmpwMXZAZAcjB4"
                  }
               }
            },
            "id": "t_1066256636795001"
         },
         {
            "messages": {
               "data": [
                  {
                     "created_time": "2016-05-12T03:15:17+0000",
                     "message": "Hi Divya.\n\nYou've got in touch with our team on mail, I believe. Let's continue the conversation there.\n\nShyam",
                     "id": "m_mid.1463022917043:5173b97e289369c727"
                  },
                  {
                     "created_time": "2016-05-10T05:54:46+0000",
                     "message": "Hi Team,\nGreetings from ADATHA!!\nI\u2019m Divya and I currently handle all of the partnerships and Business Development on our end over here at ADATHA ( www.adatha.com  ) \u2013 Award winning performance mobile AD marketing Agency.\nYour app has a great potential to generate more revenue with the help of our professional marketing team.\nWe worked on several apps and we have a very good track record of promoting apps.\nSome of our clients are Amazon, Wechat, Skype, LINE, Myntra, Flipkart, Snapdeal, PayTM, Clash of Clans, etc.,\nYou can pay us on download basis.\nIncent CPI \u2013 18 INR\nNon Incent CPI - 45 INR\nAlso we do CPC and CPM services through our real time bidder.\nThank you for your time and consideration.  \n\nKindly loop me in with your marketing team if interested . Thanks:)",
                     "id": "m_mid.1462859685847:07dbcbe04768688c31"
                  }
               ],
               "paging": {
                  "cursors": {
                     "before": "QVFIUnBuamxsUTNwc2o5bHBVcXVJNENLNjdSb3l0LXk3NEFmRkliUTdDd01EaDgtU21jRGRuUTY4bDZADZAXJmTUlEVFRGQXdCdHlIRmdMa0xfQURMbUZAtX0dzM2RtaDBpOE5rd1psYjFKdEdjMm13ckw2Tldyd3Y0SHBvTkNkb2s2ZAmVP",
                     "after": "QVFIUmZAMSGdUS3ZAiTkpWSExzakE0ZA1AzTjVzU3ZABNm9CbTNHZADhLV1cxV1ctNm5RdEdOZAUl2OW4wT09EeW1iQ1phdEhDdFkzSnFHX2o5cXptbC1zRVVMVEktRlBZAZAGNqRThIU1pXVWEtOWdpNlBVWjFIR0MwZAEpEQ1pJcXNFRkFQUFFp"
                  }
               }
            },
            "id": "t_1268094999871284"
         },
         {
            "messages": {
               "data": [
                  {
                     "created_time": "

         },
         {
            "messages": {
               "data": [
                  {
                     "created_time": "2015-05-07T09:08:53+0000",
                     "message": "Hi Kushal.\n\nThat's an important point you've raised and we have in fact had internal discussions about it. We are working on the idea to adjust specification scores by OS. So an Apple phone will have a better spec score for battery even if it has a lower rated battery rating in mAH. Thanks for your feedback.\n\nRegards\nBuySmaart Team",
                     "id": "m_mid.1430989733255:e45ee920deac898520"
                  },
                  {
                     "created_time": "2015-05-07T08:14:07+0000",
                     "message": "Hi\nI just read an article about your comparison website. Just wanted to tell you that different operating systems have similar performance with same specifications. Maybe you can also take that into account. Same with the battery capacity. Apple's phones with low mAh batteries run for as long as other phones with higher battery specs. Even for different android versions its different even for the same phone. Taking all this into account, I dont think I got the desired results.\nJust wanted to tell you that because I loved your implementation of AI. Thanks.",
                     "id": "m_mid.1430986446835:447e5be974a70ff663"
                  }
               ],
               "paging": {
                  "cursors": {
                     "before": "QVFIUlNwc1FpRVpjcC1iS1BqM3RtTW5HazYxOE1nUXlTclBacjRoMzgtX0lDSkg4WS1FSHR5REZAldWFHQkplWXN5TFdtN3ZA1eWsxVmpXR3ZAjQ1pxM2xGQVdhNWc5ZATlZAaHJlczBGVHFCVGhMVENBYVZADVXRuSGx1TTQ3TEpLRmRSVkEx",
                     "after": "QVFIUm5ONDBuVWdTMFdJVXVQeHRpRmN5TjZAtQWtDM0RQX2pJTU1sbGJWaWhjX2FHOXh0SWVhQTZAQcVViTkFnWWs3ZAHFrYXAtYUtBZAHpsVklERDNFOEc0bmh4RTRXcFllekdMdm5NQ2tRelQyX1lUNmx5NXdwd3ZAKQWR2R1NjTXY2TGNj"
                  }
               }
            },
            "id": "t_1024282250937012"
         },
         {
            "messages": {
               "data": [
                  {
                     "created_time": "2015-05-07T07:22:40+0000",
                     "message": "Okay..Thanks",
                     "id": "m_mid.1430983359880:52dc833d91592e1608"
                  },
                  {
                     "created_time": "2015-05-07T07:20:25+0000",
                     "message": "Not interested. Thanks",
                     "id": "m_mid.1430983225438:0358302913a33d3996"
                  },
                  {
                     "created_time": "2015-05-07T06:40:49+0000",
                     "message": "Good Morning Sir,\n\n                                We are a group of Graduate students from Hyderabad,India.As inspired from many young innovative entrepreneurs ,  we started our own enterprise which takes the method of advertising to a new and next level.\n\n2.We can say that the concept is very simple but its very effective. Simply we can call it as \"Notebook Advertising\". Because we publicize your products/services ,using notebook covers as medium.\n\n3.This is very effective medium because every college student have to use notebooks for their academic purposes.this makes your ad  to reach many people and especially young people.\n\n4.The cost of expenditure for this type of advertising is very cheaper than any other methods.For publishing an ad on single side of notebook cover,it costs you only rupees 7/- but at the same time  each and every ad would be seen by at least 20-30 people in its lifetime  of 6-8 months,this is the highest visibility rate for any advertisement.\n\n5.We ensure that your ad would be published on high quality 250 GSM sheets and notebooks are made with white paper of 80GSM,and also these books are available at lower prices for consumers because they contain your ads which makes production costs cheaper.\n\n\n6.And also we would run a website which contains links to your sites and also your latest offers,deals so that we can keep your customers updated and also we can estimate the viewership of our ad.\n\nSome of the Incentives of this medium are \n \n\u2022Clutter free\n\u2013Only 4 Ads per book . No clutter like Hoardings or Newspaper ads\n\u2022Exclusive Distribution\n\u2013Area/Location Specific targeted sales.\n\u2022Increased Viewership\n\u2013Ads also seen by friends, family, colleagues resulting in 20x viewership.\n\u2022Evolving media\n\u2013Next Gen Advertising, an altogether new platform to Advertise aimed at the youth.\n\n                                        We have also prepared a detailed presentation on this concept.If you are interested in our concept we can present it for you.And lastly we are very thankful to your for reading our mail till last with patience.\n\n                                                        Thanking you.\n \nRaghu Veer K",
                     "id": "m_mid.1430980849082:0d634b9d6bb84ba094"
                  }
               ],
               "paging": {
                  "cursors": {
                     "before": "QVFIUkR5U3FsT3RyQkxNRUNlUVpvOWJHLXFiaU84WXdWTDd2Y0tXX2VBcHlvZAkR4X2tzcTJyX0hRZAUFiakRsUmhLcEo2a0pvVXRER3B3WnFZARDVmUHQwS0thR2ZAjc2RnQlB2VUloNWkyLXpyZAjRjeVJ0QTRoYVpxNHZA0QzN3MkFEazZA6",
                     "after": "QVFIUnYwUzludGd4WHNMRGFLZA2hrSktvY2tNQmF1T2hoY3hsRHNBVEd4TG9RWGlheUgtWG9RTzRTM1NBdTlUS0xpay1EVGdaelRHVDI5LTgxTFpoaS0tTHdXcWpLYWtDcmhxNUd4NkRaNkRtcVJyT2tnODRzWFdMbVlkR3ZArYUFIOGpW"
                  }
               }
            },
            "id": "t_798346483617054"
         }
      ],
      "paging": {
         "cursors": {
            "before": "QVFIUkxOQU84UmxBaUVsaEltR0tRelZAoWmNYZAEZAKRjJ2R3BTdzdaMWFtLXNMRHhPaFJuSERjcUlnV2FselNNVHdIZAnNBaS1nZA0tGS1dNdnNBSmpTOFMxdnJsX29rVzRCbnBHeDM1SEI2NXFYdEQtenRJS0xfSFJNakU0OUpHRjN3dXpr",
            "after": "QVFIUkljaS1oWFQtQndYLW5za3YyZA202RUpOU3VYY1RUZAXZA4RXhJcGRLM2M2el95Vy1uaEFLT2tWdkp4UE9fSTZAqZAEhxQUF1aHFiSS1kS0ZARYklSUDdaMElxbE9seTFudkpvYUFhaUVESy1uWFdhSVJKQ3lXeDVtM1d5b2txQU1KcW12"
         }
      }
   }
}]

# %%
for item in content:
    print(created_time: {}\nmessage: {}\nid: {}\n".format(item['created_time:'],item['message'],item['id']))
# Out:
#   File "<ipython-input-6-0713f81d3703>", line 2
#     print("created_time": {}\nmessage: {}\nid: {}\n".format(item['created_time:'],item['message'],item['id']))
#                         ^
# SyntaxError: invalid syntax

# %%
import requests
r = requests.get('https://graph.facebook.com/me?fields=id,name,conversations{messages.limit(10){created_time,message,from,id},id,link}&access_token=EAAKHIpZBSTYwBAF7AVnHTnGZCdNFLRklOVME4Nt7OZB2FlZBNYLZBfPebhjfHID4XL8yd8gCd4dh9lQX2TKyrwxcV7D3Rw4PLW6H2lPZBBrn0yQU6ObfcQT7w44rUs3fVx8coywNQICN2OPkvFZC2e2xpVF1nj2Cb9ZC0iNAhMnLbxLkFqCn0I1oziEDrQ3ki0nZA4KbMlZBmh8gZDZD')
r.json()
# Out:
# {u'conversations': {u'data': [{u'id': u't_620671001609400',
#     u'link': u'/enixtaAI/inbox/913262322167574/',
#     u'messages': {u'data': [{u'created_time': u'2018-03-14T21:53:13+0000',
#        u'from': {u'email': u'441918235968654@facebook.com',
#         u'id': u'441918235968654',
#         u'name': u'buysmaart'},
#        u'id': u'm_mid.$cAAHLGX9F7lFoV8YC0liJoC6SsZRI',
#        u'message': u'Thanks for reaching out. We will start the blogging soon. It is not for sale.'},
#       {u'created_time': u'2018-03-14T04:52:22+0000',
#        u'from': {u'email': u'1919145171530198@facebook.com',
#         u'id': u'1919145171530198',
#         u'name': u'Adeendren Iyan'},
#        u'id': u'm_mid.$cAAHLGX9F7lFoVB9kQViItoaFCfIW',
#        u'message': u"Hi there,\n\nI'm looking to start a site and noticed that your blog has been dormant for some time.\n\nI would love to buy your site if it is for sale. Would you be interested?\n\nBest,\nAdeendren"}],
# ...

# %%
import requests
from pprint import pprint
r = requests.get('https://graph.facebook.com/me?fields=id,name,conversations{messages.limit(10){created_time,message,from,id},id,link}&access_token=EAAKHIpZBSTYwBAF7AVnHTnGZCdNFLRklOVME4Nt7OZB2FlZBNYLZBfPebhjfHID4XL8yd8gCd4dh9lQX2TKyrwxcV7D3Rw4PLW6H2lPZBBrn0yQU6ObfcQT7w44rUs3fVx8coywNQICN2OPkvFZC2e2xpVF1nj2Cb9ZC0iNAhMnLbxLkFqCn0I1oziEDrQ3ki0nZA4KbMlZBmh8gZDZD')
pprint(r.json())
# Out:
# {u'conversations': {u'data': [{u'id': u't_620671001609400',
#                                u'link': u'/enixtaAI/inbox/913262322167574/',
#                                u'messages': {u'data': [{u'created_time': u'2018-03-14T21:53:13+0000',
#                                                         u'from': {u'email': u'441918235968654@facebook.com',
#                                                                   u'id': u'441918235968654',
#                                                                   u'name': u'buysmaart'},
#                                                         u'id': u'm_mid.$cAAHLGX9F7lFoV8YC0liJoC6SsZRI',
#                                                         u'message': u'Thanks for reaching out. We will start the blogging soon. It is not for sale.'},
#                                                        {u'created_time': u'2018-03-14T04:52:22+0000',
# ...

# %%
sample_object = {'Name':'John', 'Location':{'City':'Los Angeles','State':'CA'}}

# %%
from pandas.io.json import json_normalize
json_normalize(sample_object)
# Out:
#   Location.City Location.State  Name
# 0   Los Angeles             CA  John

# %%
dic = [
    {"a": 1, "b": 2, "c": {"d": 3, "e": 4}},
    {"a": 0.5, "c": {"d": 3.2}},
    {"a": 0.8, "b": 1.8},
]

# %%
dic_flattened = [flatten(d) for d in dic]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-d5feeeefec58> in <module>()
# ----> 1 dic_flattened = [flatten(d) for d in dic]
#
# NameError: name 'flatten' is not defined

# %%
flatten(dic)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-20-ca625a7dad8d> in <module>()
# ----> 1 from flatten_json import flatten
#       2 flatten(dic)
#
# ImportError: No module named flatten_json
